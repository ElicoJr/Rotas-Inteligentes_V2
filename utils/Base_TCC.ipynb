# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import json
import geopandas as gpd

# %%
tec = pd.read_parquet("/Rotas-Inteligentes/data/atendTec.parquet")
com = pd.read_parquet("/Rotas-Inteligentes/data/ServCom.parquet")
equipes = pd.read_parquet("/Rotas-Inteligentes/data/equipes.parquet")

# %%
display(tec.shape, com.shape, equipes.shape)
# Out:
# (65367, 22)
# (253958, 18)
# (31346, 14)

# %%
localidades = gpd.read_file("/Rotas-Inteligentes/shp_localidade/LocalidadesSGD.shp")

# %%
localidades = localidades.set_crs(epsg=31980)

# %%
localidades = localidades.to_crs(epsg=4326)

# %%
localidades = localidades[localidades["CODLOCAL"] == 1]

# %%
localidades
# Out:
#     IDENTIFICA        ID             NAME  SOURCE_ID SOURCE_DAT SOURCE_D1  \
# 23        24.0    4328.0      PORTO VELHO        NaN       None      None
# 81        82.0  180351.0  PORTO VELHO_FIC        NaN       None      None
#
#     CODLOCAL  CODIBGE REGIONAL         POLO   SUP  \
# 23       1.0      NaN  1.NORTE  PORTO VELHO  None
# 81       1.0      NaN  1.NORTE  PORTO VELHO  None
#
#                                              geometry
# 23  POLYGON ((-63.93601 -8.59286, -63.93412 -8.588...
# 81  POLYGON ((-63.53473 -7.97433, -63.62078 -7.969...

# %%
tec["geometry"] = gpd.points_from_xy(tec["LONGITUDE"], tec["LATITUDE"])
tec = gpd.GeoDataFrame(tec, geometry="geometry")
tec = tec.set_crs(epsg=4326)

# %%
base_tec = gpd.sjoin(tec, localidades[["geometry"]], how="inner", predicate='within')

# %%
base_tec.shape
# Out:
# (64606, 24)

# %%
com["geometry"] = gpd.points_from_xy(com["LONGITUDE"], com["LATITUDE"])
com = gpd.GeoDataFrame(com, geometry="geometry")
com = com.set_crs(epsg=4326)

# %%
base_com = gpd.sjoin(com, localidades[["geometry"]], how="inner", predicate='within')

# %%
base_com.shape
# Out:
# (250827, 20)

# %%
base_com = pd.DataFrame(base_com.drop(columns=["geometry", "index_right"]))

# %%
base_tec = pd.DataFrame(base_tec.drop(columns=["geometry", "index_right"]))

# %%
base_tec.to_parquet("/Rotas-Inteligentes/data/atendTec.parquet", index=False, compression="snappy")
base_com.to_parquet("/Rotas-Inteligentes/data/ServCom.parquet", index=False, compression="snappy")

# %%
base_tec.to_csv("/Rotas-Inteligentes/data/atendTec.csv", index=False, sep=";", encoding="utf-8-sig", decimal=",", float_format="%.6f")
base_com.to_csv("/Rotas-Inteligentes/data/ServCom.csv", index=False, sep=";", encoding="utf-8-sig", decimal=",", float_format="%.6f")

# %%
frames = []
for file in os.listdir("/Rotas-Inteligentes/results_v3/"):
    if file.endswith(".parquet") and file.startswith("atribuicoes_"):
        df = pd.read_parquet(os.path.join("/Rotas-Inteligentes/results_v3/", file))
        frames.append(df)
df = pd.concat(frames)

# %%
display(
    tec.shape, 
    com.shape, 
    df.shape
)
# Out:
# (65367, 22)
# (253958, 18)
# (152226, 55)

# %% [markdown]
# ## Tratamento da base

# %%
tec["TIPSERV"] = "T"
tec["DATA_VENC"] = tec["DH_INICIO"]
tec = tec.rename(
    columns={
        "DH_INICIO": "DATA_SOL",
        "DH_ALOCACAO": "DATASAIDA",
        "DH_CHEGADA": "DATAINITRAB",
        "DH_FINAL": "DATATERTRAB",
    }
)

# %%
tec = tec.drop_duplicates(subset=["NUMOS"])
com = com.drop_duplicates(subset=["NUMOS"])

# %%
com = com[com["DATA_VENC"] > com["DATA_SOL"]]

# %%
com = com.rename(columns={"NUM_CDC": "DEFEITO_FALHA"})
com["TIPO_BASE"] = "COMERCIAL"

# %%
tec["CODSERV"] = np.nan

# %%
com.loc[com["TD"] >= 5]["TD"].describe()
# Out:
# count    106366.000000
# mean         19.790451
# std          41.889856
# min           5.000000
# 25%           8.830000
# 50%          14.250000
# 75%          24.320000
# max       11549.600000
# Name: TD, dtype: float64

# %%
display(com.columns, tec.columns)
# Out:
# Index(['NUMOS', 'TIPSERV', 'CODSERV', 'DATA_SOL', 'DATA_VENC', 'DEFEITO_FALHA',
#        'LATITUDE', 'LONGITUDE', 'DATASAIDA', 'DATAINITRAB', 'DATATERTRAB',
#        'EQUIPE', 'TD', 'TE', 'ANO', 'MES', 'EUSD_FIO_B', 'EUSD', 'TIPO_BASE'],
#       dtype='object')
# Index(['TIPO_BASE', 'NUMOS', 'ABRANGENCIA', 'DEFEITO_FALHA', 'LOCALIDADE',
#        'LOCALIZACAO', 'NOX', 'NOY', 'DATA_SOL', 'DATASAIDA', 'DATAINITRAB',
#        'DATATERTRAB', 'TP', 'TD', 'TE', 'EQUIPE', 'ANO', 'MES', 'EUSD',
#        'EUSD_FIO_B', 'LATITUDE', 'LONGITUDE', 'TIPSERV', 'DATA_VENC',
#        'CODSERV'],
#       dtype='object')

# %%
serv = pd.concat([tec, com], ignore_index=True).to_clipboard(
    index=False, decimal=",", sep=";"
)

# %%
serv = pd.concat([tec, com], ignore_index=True).drop_duplicates(subset=["NUMOS"])

# %%
serv.shape
# Out:
# (241420, 25)

# %%
equipes.to_clipboard(index=False, decimal=",", sep=";")

# %%
df.groupby(["numos"]).size().reset_index(name="counts").sort_values(
    by="counts", ascending=False
).shape
# Out:
# (151575, 2)

# %%
pd.read_parquet(
    "/Rotas-Inteligentes/results_v3/atribuicoes_2023-01-01.parquet"
).to_clipboard(index=False, decimal=",", sep=";")

# %%
equipes["BASE_LON"] = -63.885464691387746
equipes["BASE_LAT"] = -8.738508095069408

# %%
equipes.to_parquet("/Rotas-Inteligentes/data/equipes.parquet", index=False)

# %%
equipes.head()
# Out:
#       TIP_EQUIPE   EQUIPE      DT_REF          DTHAPS_INI          DTHAPS_FIM  \
# 23649          I  PVLSN81  2023-01-01 2023-01-01 05:59:02 2023-01-01 14:51:30
# 30547          I  PVOSN67  2023-01-01 2023-01-01 06:00:08 2023-01-01 15:01:27
# 24075          I  PVLSN84  2023-01-01 2023-01-01 06:00:15 2023-01-01 14:56:07
# 30421          I  PVOSN66  2023-01-01 2023-01-01 06:00:31 2023-01-01 15:10:57
# 23406          I  PVLSN80  2023-01-01 2023-01-01 08:00:59 2023-01-01 18:20:18
#
#        HH_TRAB   DATA_INICIO_TURNO      DATA_FIM_TURNO  HORA_BRUTA  HH_TOTAL  \
# 23649     8.87 2023-01-01 06:00:00 2023-01-01 15:00:00         8.0    532.47
# 3   2023-01-01 14:51:30  ...     NaN                 NaT                 NaT
# 4   2023-01-01 14:51:30  ...     NaN                 NaT                 NaT
# ..                  ...  ...     ...                 ...                 ...
# 224 2025-01-01 06:07:27  ...     NaN                 NaT                 NaT
# 225 2025-01-01 06:07:27  ...     3.0 2024-12-31 19:23:12 2025-01-04 08:00:00
# 226 2025-01-01 06:07:27  ...    83.0 2024-12-31 15:11:39 2025-02-03 23:59:59
# 227 2025-01-01 06:07:27  ...     NaN                 NaT                 NaT
# 228 2025-01-01 06:07:27  ...     NaN                 NaT                 NaT
#
#      num_cdc           datasaida         datainitrab         datatertrab  \
# 0       <NA>                 NaT                 NaT                 NaT
# 1       <NA>                 NaT                 NaT                 NaT
# 2       <NA>                 NaT                 NaT                 NaT
# 3       <NA>                 NaT                 NaT                 NaT
# 4       <NA>                 NaT                 NaT                 NaT
# ..       ...                 ...                 ...                 ...
# 224     <NA>                 NaT                 NaT                 NaT
# 225  2231016 2025-01-02 09:33:46 2025-01-02 09:51:30 2025-01-02 09:54:15
# 226  1246276 2024-12-31 15:13:38 2024-12-31 15:13:44 2024-12-31 15:52:23
# 227     <NA>                 NaT                 NaT                 NaT
# 228     <NA>                 NaT                 NaT                 NaT
#
#        job_id_vroom  distancia_vroom  duracao_vroom
# 0    20230000000001             None        12161.0
# 1    20230000000006             None        12161.0
# 2    20230000000011             None        12161.0
# 3    20230000000013             None        12161.0
# 4    20230000000015             None        12161.0
# ..              ...              ...            ...
# 224  20240000407260             None         6436.0
# 225       120631516             None         6436.0
# 226       120619518             None         6436.0
# 227  20240000407681             None         6436.0
# 228  20240000407368             None         6436.0
#
# [152226 rows x 55 columns]

# %%
serv["tipo_serv"] = serv["TIPSERV"].map({"T": "técnico", "C": "comercial"})

# %%
serv.columns = serv.columns.str.lower()

# %%
atendimento = pd.merge(df[["numos", "tipo_serv"]], serv[["numos", "tipo_serv"]], on=["numos"], how="outer", indicator=True)

# %%
atendimento._merge.value_counts()
# Out:
# _merge
# both          152226
# right_only     89845
# left_only          0
# Name: count, dtype: int64

# %%
df = pd.DataFrame(df)

# %%
df.to_clipboard(index=False, decimal=",", sep=";")

# %%
BASE_LON = -63.885464691387746
BASE_LAT = -8.738508095069408

# %%
baseTec = pd.read_parquet("E:/Rotas-Inteligentes/data/BaseTec.parquet")
baseCom = pd.read_parquet("E:/Rotas-Inteligentes/data/ServCom.parquet")

# %%
baseCom.shape
# Out:
# (253958, 18)

# %%
baseTec.shape
# Out:
# (65367, 11)

# %%
v4 = pd.read_parquet(r"E:\Rotas-Inteligentes\results_v4\atribuicoes_2023-01-01.parquet")

# %%
v3 = pd.read_parquet(r"E:\Rotas-Inteligentes\results_v3\atribuicoes_2023-01-01.parquet")

# %%
display(v3.shape, v4.shape)
# Out:
# (52, 29)
# (52, 27)

# %%
v3.columns
# Out:
# Index(['tipo_serv', 'numos', 'datasol', 'dataven', 'datater_trab', 'TD', 'TE',
#        'equipe', 'dthaps_ini', 'dthaps_fim_ajustado', 'inicio_turno',
#        'fim_turno', 'dthpausa_ini', 'dthpausa_fim', 'dth_chegada_estimada',
#        'dth_final_estimada', 'fim_turno_estimado', 'eta_source', 'base_lon',
#        'base_lat', 'chegada_base', 'latitude', 'longitude', 'dt_ref', 'EUSD',
#        'EUSD_FIO_B', 'job_id_vroom', 'distancia_vroom', 'duracao_vroom'],
#       dtype='object')

# %%
v4[['equipe', 'dthaps_ini', 'dthaps_fim_ajustado', 'inicio_turno',
       'fim_turno', 'dthpausa_ini', 'dthpausa_fim', 'dth_chegada_estimada',
       'dth_final_estimada', 'fim_turno_estimado', 'chegada_base', 'EUSD']]
# Out:
#      equipe dthaps_ini dthaps_fim_ajustado inicio_turno fim_turno  \
# 0   PVLSN81        NaT                 NaT          NaT       NaT
# 1   PVLSN81        NaT                 NaT          NaT       NaT
# 2   PVLSN81        NaT                 NaT          NaT       NaT
# 3   PVLSN81        NaT                 NaT          NaT       NaT
# 4   PVLSN81        NaT                 NaT          NaT       NaT
# 5   PVLSN81        NaT                 NaT          NaT       NaT
# 6   PVLSN81        NaT                 NaT          NaT       NaT
# 7   PVLSN22        NaT                 NaT          NaT       NaT
# 8   PVLSN22        NaT                 NaT          NaT       NaT
# 9   PVLSN22        NaT                 NaT          NaT       NaT
# 10  PVLSN22        NaT                 NaT          NaT       NaT
# 11  PVLSN22        NaT                 NaT          NaT       NaT
# 12  PVOSN64        NaT                 NaT          NaT       NaT
# 13  PVOSN64        NaT                 NaT          NaT       NaT
# 14  PVOSN64        NaT                 NaT          NaT       NaT
# 15  PVOSN64        NaT                 NaT          NaT       NaT
# 16  PVLSN09        NaT                 NaT          NaT       NaT
# 17  PVOSN64        NaT                 NaT          NaT       NaT
# 18  PVOSN64        NaT                 NaT          NaT       NaT
# 19  PVLSN09        NaT                 NaT          NaT       NaT
# 20  PVLSN09        NaT                 NaT          NaT       NaT
# 21  PVOSN64        NaT                 NaT          NaT       NaT
# 22  PVOSN64        NaT                 NaT          NaT       NaT
# 23  PVLSN09        NaT                 NaT          NaT       NaT
# 24  PVOSN64        NaT                 NaT          NaT       NaT
# 25  PVLSN09        NaT                 NaT          NaT       NaT
# 26  PVOSN64        NaT                 NaT          NaT       NaT
# 27  PVOSN64        NaT                 NaT          NaT       NaT
# 28  PVOSN64        NaT                 NaT          NaT       NaT
# 29  PVOSN64        NaT                 NaT          NaT       NaT
# 30  PVOSN64        NaT                 NaT          NaT       NaT
# 31  PVOSN64        NaT                 NaT          NaT       NaT
# 32  PVLSN91        NaT                 NaT          NaT       NaT
# 33  PVLSN91        NaT                 NaT          NaT       NaT
# 34  PVLSN91        NaT                 NaT          NaT       NaT
# 35  PVLSN91        NaT                 NaT          NaT       NaT
# 36  PVLSN06        NaT                 NaT          NaT       NaT
# 37  PVLSN06        NaT                 NaT          NaT       NaT
# 38  PVLSN91        NaT                 NaT          NaT       NaT
# 39  PVLSN91        NaT                 NaT          NaT       NaT
# 40  PVLSN06        NaT                 NaT          NaT       NaT
# 41  PVLSN06        NaT                 NaT          NaT       NaT
# 42  PVLSN06        NaT                 NaT          NaT       NaT
# 43  PVLSN06        NaT                 NaT          NaT       NaT
# 44  PVLSN06        NaT                 NaT          NaT       NaT
# 45  PVLSN06        NaT                 NaT          NaT       NaT
