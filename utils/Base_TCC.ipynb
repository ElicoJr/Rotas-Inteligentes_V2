# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import json

# %%
tec = pd.read_parquet("/Rotas-Inteligentes/data/atendTec.parquet")
com = pd.read_parquet("/Rotas-Inteligentes/data/ServCom.parquet")
equipes = pd.read_parquet("/Rotas-Inteligentes/data/equipes.parquet")

# %%
frames = []
for file in os.listdir("/Rotas-Inteligentes/results_v3/"):
    if file.endswith(".parquet") and file.startswith("atribuicoes_"):
        df = pd.read_parquet(os.path.join("/Rotas-Inteligentes/results_v3/", file))
        frames.append(df)
df = pd.concat(frames)

# %%
display(
    tec.shape, 
    com.shape, 
    df.shape
)
# Out:
# (65367, 22)
# (253958, 18)
# (152226, 55)

# %% [markdown]
# ## Tratamento da base

# %%
tec["TIPSERV"] = "T"
tec["DATA_VENC"] = tec["DH_INICIO"]
tec = tec.rename(
    columns={
        "DH_INICIO": "DATA_SOL",
        "DH_ALOCACAO": "DATASAIDA",
        "DH_CHEGADA": "DATAINITRAB",
        "DH_FINAL": "DATATERTRAB",
    }
)

# %%
tec = tec.drop_duplicates(subset=["NUMOS"])
com = com.drop_duplicates(subset=["NUMOS"])

# %%
com = com[com["DATA_VENC"] > com["DATA_SOL"]]

# %%
com = com.rename(columns={"NUM_CDC": "DEFEITO_FALHA"})
com["TIPO_BASE"] = "COMERCIAL"

# %%
tec["CODSERV"] = np.nan

# %%
com.loc[com["TD"] >= 5]["TD"].describe()
# Out:
# count    106366.000000
# mean         19.790451
# std          41.889856
# min           5.000000
# 25%           8.830000
# 50%          14.250000
# 75%          24.320000
# max       11549.600000
# Name: TD, dtype: float64

# %%
display(com.columns, tec.columns)
# Out:
# Index(['NUMOS', 'TIPSERV', 'CODSERV', 'DATA_SOL', 'DATA_VENC', 'DEFEITO_FALHA',
#        'LATITUDE', 'LONGITUDE', 'DATASAIDA', 'DATAINITRAB', 'DATATERTRAB',
#        'EQUIPE', 'TD', 'TE', 'ANO', 'MES', 'EUSD_FIO_B', 'EUSD', 'TIPO_BASE'],
#       dtype='object')
# Index(['TIPO_BASE', 'NUMOS', 'ABRANGENCIA', 'DEFEITO_FALHA', 'LOCALIDADE',
#        'LOCALIZACAO', 'NOX', 'NOY', 'DATA_SOL', 'DATASAIDA', 'DATAINITRAB',
#        'DATATERTRAB', 'TP', 'TD', 'TE', 'EQUIPE', 'ANO', 'MES', 'EUSD',
#        'EUSD_FIO_B', 'LATITUDE', 'LONGITUDE', 'TIPSERV', 'DATA_VENC',
#        'CODSERV'],
#       dtype='object')

# %%
serv = pd.concat([tec, com], ignore_index=True).to_clipboard(
    index=False, decimal=",", sep=";"
)

# %%
serv = pd.concat([tec, com], ignore_index=True).drop_duplicates(subset=["NUMOS"])

# %%
serv.shape
# Out:
# (241420, 25)

# %%
equipes.to_clipboard(index=False, decimal=",", sep=";")

# %%
df.groupby(["numos"]).size().reset_index(name="counts").sort_values(
    by="counts", ascending=False
).shape
# Out:
# (151575, 2)

# %%
pd.read_parquet(
    "/Rotas-Inteligentes/results_v3/atribuicoes_2023-01-01.parquet"
).to_clipboard(index=False, decimal=",", sep=";")

# %%
equipes["BASE_LON"] = -63.885464691387746
equipes["BASE_LAT"] = -8.738508095069408

# %%
equipes.to_parquet("/Rotas-Inteligentes/data/equipes.parquet", index=False)

# %%
equipes.head()
# Out:
#       TIP_EQUIPE   EQUIPE      DT_REF          DTHAPS_INI          DTHAPS_FIM  \
# 23649          I  PVLSN81  2023-01-01 2023-01-01 05:59:02 2023-01-01 14:51:30
# 30547          I  PVOSN67  2023-01-01 2023-01-01 06:00:08 2023-01-01 15:01:27
# 24075          I  PVLSN84  2023-01-01 2023-01-01 06:00:15 2023-01-01 14:56:07
# 30421          I  PVOSN66  2023-01-01 2023-01-01 06:00:31 2023-01-01 15:10:57
# 23406          I  PVLSN80  2023-01-01 2023-01-01 08:00:59 2023-01-01 18:20:18
#
#        HH_TRAB   DATA_INICIO_TURNO      DATA_FIM_TURNO  HORA_BRUTA  HH_TOTAL  \
# 23649     8.87 2023-01-01 06:00:00 2023-01-01 15:00:00         8.0    532.47
# 30547     9.02 2023-01-01 06:00:00 2023-01-01 15:00:00         8.0    541.32
# 24075     8.93 2023-01-01 06:00:00 2023-01-01 15:00:00         8.0    535.87
# 30421     9.17 2023-01-01 06:00:00 2023-01-01 15:00:00         8.0    550.43
# 23406    10.32 2023-01-01 08:00:00 2023-01-01 18:00:00         8.0    619.32
#
#       DTHAPS_FIM_AJUSTADO  HH_TRAB_AJUSTADO                  DTHPAUSA_FIM  \
# 23649 2023-01-01 14:51:30              8.87 2023-01-01 11:25:08.000000000
# 30547 2023-01-01 15:01:27              9.02 2023-01-01 11:30:44.000000000
# 24075 2023-01-01 14:56:07              8.93 2023-01-01 11:28:09.000000000
# 30421 2023-01-01 15:10:57              9.17 2023-01-01 11:35:36.999999999
# 23406 2023-01-01 18:20:18             10.32 2023-01-01 14:10:35.000000000
#
#                        DTHPAUSA_INI
# 23649 2023-01-01 10:25:08.000000000
# 30547 2023-01-01 10:30:44.000000000
# 24075 2023-01-01 10:28:09.000000000
# 30421 2023-01-01 10:35:36.999999999
# 23406 2023-01-01 13:10:35.000000000

# %%
Atendimentos = pd.merge(
    df[]
# Out:
#      tipo_serv           numos             datasol             dataven  \
# 0      técnico  20230000000001 2023-01-01 00:22:00                 NaT
# 1      técnico  20230000000006 2023-01-01 01:32:52                 NaT
# 2      técnico  20230000000011 2023-01-01 01:49:54                 NaT
# 3      técnico  20230000000013 2023-01-01 01:53:46                 NaT
# 4      técnico  20230000000015 2023-01-01 02:19:30                 NaT
# ..         ...             ...                 ...                 ...
# 224    técnico  20240000407260 2024-12-31 11:31:00                 NaT
# 225  comercial       120631516 2024-12-31 19:23:12 2025-01-04 08:00:00
# 226  comercial       120619518 2024-12-31 15:11:39 2025-02-03 23:59:59
# 227    técnico  20240000407681 2024-12-31 20:22:17                 NaT
# 228    técnico  20240000407368 2024-12-31 14:19:39                 NaT
#
#            datater_trab     TD     TE   equipe          dthaps_ini  \
# 0   2023-06-06 14:08:14  17.13  44.00  PVLSN81 2023-01-01 05:59:02
# 1   2023-01-01 04:55:34  20.65  27.00  PVLSN81 2023-01-01 05:59:02
# 2   2023-01-01 06:58:19  17.25  27.32  PVLSN81 2023-01-01 05:59:02
# 3   2023-01-01 09:59:53  42.55  64.37  PVLSN81 2023-01-01 05:59:02
# 4   2023-01-01 03:53:27  17.05  35.90  PVLSN81 2023-01-01 05:59:02
# ..                  ...    ...    ...      ...                 ...
# 224 2024-12-31 22:52:17  31.40  44.00  PVLPL46 2024-12-31 21:03:17
# 225 2025-01-02 09:54:15  17.73   2.75  PVLPL46 2024-12-31 21:03:17
# 226 2024-12-31 15:52:23   0.10  38.65  PVLPL46 2024-12-31 21:03:17
# 227 2025-01-02 10:03:16  32.97  28.85  PVLPL46 2024-12-31 21:03:17
# 228 2024-12-31 15:20:00  11.95  16.68  PVLPL46 2024-12-31 21:03:17
#
#     dthaps_fim_ajustado  ... codserv            data_sol           data_venc  \
# 0   2023-01-01 14:51:30  ...     NaN                 NaT                 NaT
# 1   2023-01-01 14:51:30  ...     NaN                 NaT                 NaT
# 2   2023-01-01 14:51:30  ...     NaN                 NaT                 NaT
# 3   2023-01-01 14:51:30  ...     NaN                 NaT                 NaT
# 4   2023-01-01 14:51:30  ...     NaN                 NaT                 NaT
# ..                  ...  ...     ...                 ...                 ...
# 224 2025-01-01 06:07:27  ...     NaN                 NaT                 NaT
# 225 2025-01-01 06:07:27  ...     3.0 2024-12-31 19:23:12 2025-01-04 08:00:00
# 226 2025-01-01 06:07:27  ...    83.0 2024-12-31 15:11:39 2025-02-03 23:59:59
# 227 2025-01-01 06:07:27  ...     NaN                 NaT                 NaT
# 228 2025-01-01 06:07:27  ...     NaN                 NaT                 NaT
#
#      num_cdc           datasaida         datainitrab         datatertrab  \
# 0       <NA>                 NaT                 NaT                 NaT
# 1       <NA>                 NaT                 NaT                 NaT
# 2       <NA>                 NaT                 NaT                 NaT
# 3       <NA>                 NaT                 NaT                 NaT
# 4       <NA>                 NaT                 NaT                 NaT
# ..       ...                 ...                 ...                 ...
# 224     <NA>                 NaT                 NaT                 NaT
# 225  2231016 2025-01-02 09:33:46 2025-01-02 09:51:30 2025-01-02 09:54:15
# 226  1246276 2024-12-31 15:13:38 2024-12-31 15:13:44 2024-12-31 15:52:23
# 227     <NA>                 NaT                 NaT                 NaT
# 228     <NA>                 NaT                 NaT                 NaT
#
#        job_id_vroom  distancia_vroom  duracao_vroom
# 0    20230000000001             None        12161.0
# 1    20230000000006             None        12161.0
# 2    20230000000011             None        12161.0
# 3    20230000000013             None        12161.0
# 4    20230000000015             None        12161.0
# ..              ...              ...            ...
# 224  20240000407260             None         6436.0
# 225       120631516             None         6436.0
# 226       120619518             None         6436.0
# 227  20240000407681             None         6436.0
# 228  20240000407368             None         6436.0
#
# [152226 rows x 55 columns]

# %%
serv["tipo_serv"] = serv["TIPSERV"].map({"T": "técnico", "C": "comercial"})

# %%
serv.columns = serv.columns.str.lower()

# %%
atendimento = pd.merge(df[["numos", "tipo_serv"]], serv[["numos", "tipo_serv"]], on=["numos"], how="outer", indicator=True)

# %%
atendimento._merge.value_counts()
# Out:
# _merge
# both          152226
# right_only     89845
# left_only          0
# Name: count, dtype: int64

# %%
df = pd.DataFrame(df)

# %%
df.to_clipboard(index=False, decimal=",", sep=";")

# %%
BASE_LON = -63.885464691387746
BASE_LAT = -8.738508095069408

# %%
baseTec = pd.read_parquet("E:/Rotas-Inteligentes/data/BaseTec.parquet")
baseCom = pd.read_parquet("E:/Rotas-Inteligentes/data/ServCom.parquet")

# %%
baseCom.shape
# Out:
# (253958, 18)

# %%
baseTec.shape
# Out:
# (65367, 11)
